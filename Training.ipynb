# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

df = pd.read_csv(r"C:\Users\tyagi\OneDrive\Desktop\Pokemash 3\Tryout\Training.csv", delimiter=';', on_bad_lines='skip')
df.head()
# Out:
#                  track_id                               track_name  \
# 0  5aAx2yezTd8zXrkmtKl66Z                                  Starboy
# 1  5aAx2yezTd8zXrkmtKl66Z                                  Starboy
# 2  7BKLCZ1jbUBVqRi2FVlTVw                                   Closer
# 3  7BKLCZ1jbUBVqRi2FVlTVw                                   Closer
# 4  5knuzwU65gJK7IF5yJsuaW  Rockabye (feat. Sean Paul & Anne-Marie)
#
#    track_popularity  track_number                album_id  \
# 0                 0             1  09fggMHib4YkOtwQNXEBII
# 1                 0             1  09fggMHib4YkOtwQNXEBII
# 2                84             1  0rSLgV8p5FzfnqlEk4GzxE
# 3                84             1  0rSLgV8p5FzfnqlEk4GzxE
# 4                75             1  3meZFplbMmji648oWUNEfQ
#
#                                 album_name  \
# 0                                  Starboy
# 1                                  Starboy
# 2                                   Closer
# ...

# %%
# df.to_csv(r"C:\Users\tyagi\OneDrive\Desktop\Pokemash 3\Tryout\Training.csv", index=False)

# %%
df.describe()
# Out:
#        track_popularity  track_number  album_track_number  album_popularity  \
# count      74660.000000  74660.000000        74660.000000      74660.000000
# mean          57.851661      3.843892            3.843892         52.386244
# std           29.514677      4.390576            4.390576         27.851247
# min            0.000000      1.000000            1.000000          0.000000
# 25%           57.000000      1.000000            1.000000         47.000000
# 50%           71.000000      1.000000            1.000000         62.000000
# 75%           77.000000      5.000000            5.000000         72.000000
# max           92.000000     76.000000           76.000000         86.000000
#
#          artist_num  artist_followers  artist_popularity          rank  \
# count  74660.000000      7.466000e+04       74660.000000  74660.000000
# mean       2.233003      1.992528e+07          79.868711     99.574819
# ...

# %%
from sklearn.model_selection import train_test_split
train, test = train_test_split(df, test_size=0.99)
train.describe()
# Out:
#        track_popularity  track_number  album_track_number  album_popularity  \
# count        746.000000    746.000000          746.000000        746.000000
# mean          58.872654      3.880697            3.880697         53.336461
# std           29.059183      4.467989            4.467989         27.257769
# min            0.000000      1.000000            1.000000          0.000000
# 25%           60.000000      1.000000            1.000000         50.000000
# 50%           71.000000      1.000000            1.000000         63.000000
# 75%           77.000000      5.000000            5.000000         71.000000
# max           90.000000     22.000000           22.000000         86.000000
#
#        artist_num  artist_followers  artist_popularity        rank  \
# count  746.000000      7.460000e+02         746.000000  746.000000
# mean     2.262735      1.961166e+07          80.180965   93.935657
# std      1.286222      2.217889e+07           9.403596   56.426075
# ...
